# %% [markdown]
# ## Importações

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import chi2_contingency

# %% [markdown]
# ## Uso da Biblioteca Pandas

# %%
#Importando planilhas
db = pd.read_excel('/Users/anacariane/Desktop/programaria/planilha_modulo3.xlsx')

# %%
db
# Out:
#       Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.000000       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd  32.000000       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.000000       50-54
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.000000       25-29
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49
# ...          ...                               ...        ...         ...
# 4268        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp  26.000000       25-29
# 4269        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp  30.000000       30-34
# 4270        4268  00zw9ks9d40z4u00zz3d20iix65qpli3  29.000000       25-29
# 4271        4269  00xu7yujd7s57emj00xu7y0c3njix3de  20.205479       17-21
# 4272        4270  00lb35llmdsidpa00lb35qcdysnzvhv7  24.000000       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# ...

# %%
db.head(10)
# Out:
#    Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.000000       35-39
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd  32.000000       30-34
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.000000       50-54
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.000000       25-29
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49
# 5           5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v  32.000000       30-34
# 6           6  zytlxsdgalh22cgrijvzytlxa49i8yzx  21.000000       17-21
# 7           7  zyc0twzno2sm5or5ovoxzyc0twz0300d  31.000000       30-34
# 8           8  zy4o5dk6iuxpdwgzy4o58xvd6ykwohrj  33.000000       30-34
# 9           9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j  31.153517         55+
#
#       GENERO COR/RACA/ETNIA  PCD  \
# 0  Masculino          Parda  Não
# 1  Masculino          Parda  Não
# 2  Masculino         Branca  Não
# 3  Masculino         Branca  Não
# ...

# %%
db.tail()
# Out:
#       Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 4268        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp  26.000000       25-29
# 4269        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp  30.000000       30-34
# 4270        4268  00zw9ks9d40z4u00zz3d20iix65qpli3  29.000000       25-29
# 4271        4269  00xu7yujd7s57emj00xu7y0c3njix3de  20.205479       17-21
# 4272        4270  00lb35llmdsidpa00lb35qcdysnzvhv7  24.000000       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 4268  Masculino         Branca  Não
# 4269   Feminino         Branca  Não
# 4270  Masculino         Branca  Não
# 4271  Masculino         Branca  Não
# 4272  Masculino         Branca  Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA ASPECTOS_PREJUDICADOS  \
# 4268                                                NaN                   NaN
# 4269  Não acredito que minha experiência profissiona...                   NaN
# ...

# %%
db.shape
# Out:
# (4273, 49)

# %%
len(db)
# Out:
# 4273

# %%
db.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERAÇÃO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4273 entries, 0 to 4272
# Data columns (total 49 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4273 non-null   int64
#  1   ID                                                                                                                         4273 non-null   object
#  2   IDADE                                                                                                                      4273 non-null   float64
# ...

# %%
db.describe()
# Out:
#         Unnamed: 0        IDADE  MUDOU DE ESTADO?      GESTOR?       SALARIO
# count  4273.000000  4273.000000       4173.000000  3696.000000   4273.000000
# mean   2134.176457    31.161870          0.806374     0.193452   9911.334697
# std    1233.374579     6.864301          0.395186     0.395058   8311.333229
# min       0.000000    18.000000          0.000000     0.000000     35.000000
# 25%    1066.000000    26.000000          1.000000     0.000000   4759.000000
# 50%    2134.000000    30.000000          1.000000     0.000000   7625.500000
# 75%    3202.000000    35.000000          1.000000     0.000000  11796.000000
# max    4270.000000    54.000000          1.000000     1.000000  63813.000000

# %% [markdown]
# ## Repetindo a Primeira Análise

# %%
db[db['GENERO']!='Masculino']
# Out:
#       Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v  32.000000       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d  31.000000       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j  31.153517         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i  25.000000       25-29
# ...          ...                               ...        ...         ...
# 4250        4248  070o4zayoboztox764qu070o4zafbqrd  27.000000       25-29
# 4253        4251  068hhicrqggu068huq0l2ab3g7liagy8  34.000000       30-34
# 4260        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw  25.000000       25-29
# 4261        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w  28.000000       25-29
# 4269        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp  30.000000       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# ...

# %%
db[db['GENERO']=='Feminino']
# Out:
#       Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v  32.000000       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d  31.000000       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j  31.153517         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i  25.000000       25-29
# ...          ...                               ...        ...         ...
# 4250        4248  070o4zayoboztox764qu070o4zafbqrd  27.000000       25-29
# 4253        4251  068hhicrqggu068huq0l2ab3g7liagy8  34.000000       30-34
# 4260        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw  25.000000       25-29
# 4261        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w  28.000000       25-29
# 4269        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp  30.000000       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# ...

# %%
db[db['GENERO'].str.contains('não', na=False)]
# Out:
#       Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 232          232  y7qianl5nty7oyk1bsfua49hjoi3oyk1  27.000000       25-29
# 564          562  vhuw8xnpbmj6oh20xovhuwcbdl4a12ni  29.000000       25-29
# 1486        1484  netaq01pialkmhjxfenetaqwtcw7jdec  26.000000       25-29
# 1530        1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1  31.153517         55+
# 1794        1792  l0r14746n9veblll0r14jcp4ls5a462q  25.000000       25-29
# 1915        1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19  30.000000       30-34
# 1927        1925  jzppdwep2kpisqjjzppdh304v83cj7eu  20.205479       17-21
# 1977        1975  jknmcumdhe19i6ubgoo0pzwjknmcumzg  26.000000       25-29
# 2465        2463  ftg3alns60gn91nqftgwvdpt0ggehh89  25.000000       25-29
# 2556        2554  f5l206z0hr9uh3nz2iiff5l206c0g10o  20.000000       17-21
# 2585        2583  ev0nfkhmynogp1bxd7014ev0nfawhgze  27.000000       25-29
# 3092        3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o  26.000000       25-29
# ...

# %%
db[db['IDADE']>=30]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# ...          ...                               ...    ...         ...
# 4262        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4263        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
# 4264        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
# 4266        4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39
# 4269        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %%
db[(db["IDADE"]>30) & (db["GENERO"]=="Feminino")]
# Out:
#       Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v  32.000000       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d  31.000000       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j  31.153517         55+
# 14            14  zwez49k0jhdvfkfst4zwef137uuf4ivy  35.000000       35-39
# ...          ...                               ...        ...         ...
# 4216        4214  0gprow0ownrbfneftxf0gprow4kyrqdy  41.000000       40-44
# 4223        4221  0fgi5bnb0u9b0fgc0jmqlbnvtu12b76d  34.000000       30-34
# 4242        4240  0a5xgxb1ljmuqn0un8a10a5xg4eufs2l  37.000000       35-39
# 4249        4247  07qzabp4ujpe4oz81udmb07qzabp4h0t  34.000000       30-34
# 4253        4251  068hhicrqggu068huq0l2ab3g7liagy8  34.000000       30-34
#
#         GENERO COR/RACA/ETNIA                   PCD  \
# ...

# %%
db[(db["IDADE"]>40) & (db["COR/RACA/ETNIA"]=="Amarela")]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 107          107  z9toybzbja7n6xjjbz9f8hmofrry69tg   44.0       40-44
# 494          492  w4ld9w5goe7503cq3jqfw4ld9wj49ma1   43.0       40-44
# 557          555  vlqf7p4il3curqkgkuvlqf7r5u4e08uq   41.0       40-44
# 592          590  v9cagsq6dcf02v9clwn23i01yohn9lwn   43.0       40-44
# 645          643  uu9a5c6s3zswynhjh8cakuu9a5cfh3te   42.0       40-44
# 970          968  ryw41mfv3pq2whtfmjwryw41mlzp7yh6   43.0       40-44
# 1194        1192  q2nnk8a7iihxnxf70twcq2nnqx58fdod   42.0       40-44
# 1456        1454  nmthv38tklvb6hnmttu3qt1r4ypirgir   48.0       45-49
# 1777        1775  l8kzte32kzgceu5g9y2l8kztbh07xoh5   48.0       45-49
# 2631        2629  egjh3hu4tx1e8wag8939egjhspl5yury   48.0       45-49
# 2679        2677  e1no3l7cvidrimrpenxe1nx4fhtj55z4   43.0       40-44
# 2722        2720  dn7orffcmwqb02parydn7ornhsn3ozw3   41.0       40-44
# ...

# %%
db.groupby("GENERO")["ID"].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %%
db.groupby("GENERO", dropna=False)["ID"].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %%
db["GENERO"].value_counts(dropna=False)
# Out:
# GENERO
# Masculino               3194
# Feminino                1058
# Prefiro não informar      21
# Name: count, dtype: int64

# %%
db[db["IDADE"]>30]["NIVEL"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NIVEL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[143], line 1
# ...

# %%
db[(db["IDADE"]>30) & (db["GENERO"]=="Feminino")]["NIVEL"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NIVEL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[140], line 1
# ...

# %%
pd.pivot_table(db, values=["ID"], index=["GENERO"], columns=["GESTOR?"], aggfunc="count")
# Out:
#                         ID
# GESTOR?                0.0  1.0
# GENERO
# Feminino               754  132
# Masculino             2212  578
# Prefiro não informar     9    2

# %% [markdown]
# # Estatística Básica

# %%
lista_idades = [26,30,32,22,26,35,40,20,43,31,23]

# %%
np.sum(lista_idades)
# Out:
# np.int64(328)

# %%
len(lista_idades)
# Out:
# 11

# %%
np.sum(lista_idades)/len(lista_idades)
# Out:
# np.float64(29.818181818181817)

# %%
media = np.mean(lista_idades)
print("Média aritmética:", media)
# Out:
# Média aritmética: 29.818181818181817

# %%
lista_idades.sort()
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43]

# %%
lista_idades = [26,30,32,22,26,35,40,20,43,31,23,100]

# %%
lista_idades.sort()
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43, 100]

# %%
mediana = np.median(lista_idades)
mediana
# Out:
# np.float64(30.5)

# %% [markdown]
# #### Voltando para a tabela

# %%
db["IDADE"].mean()
# Out:
# np.float64(31.169168453657374)

# %%
db["IDADE"].median()
# Out:
# np.float64(30.0)

# %%
db["IDADE"].mode()
# Out:
# 0    27.0
# Name: IDADE, dtype: float64

# %%
db["IDADE"].std()
# Out:
# np.float64(6.902802832143122)

# %%
db["IDADE"].min()
# Out:
# np.float64(18.0)

# %%
db["IDADE"].max()
# Out:
# np.float64(54.0)

# %%
db[db["GENERO"]=="Feminino"]["IDADE"].mean()
# Out:
# np.float64(31.318051575931232)

# %%
db[db["GENERO"]=="Feminino"]["SALARIO"].mean()
# Out:
# np.float64(8673.22460496614)

# %%
db[db["GENERO"]=="Masculino"]["SALARIO"].mean()
# Out:
# np.float64(11724.552688172043)

# %% [markdown]
# # Valores Faltantes

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %% [markdown]
# ## Trabalhando coluna de gênero

# %%
db.groupby("GENERO", dropna=False)["ID"].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
db["GENERO"] = db["GENERO"].fillna("Prefiro não informar")

# %%
db.groupby("GENERO", dropna=False)["ID"].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %% [markdown]
# ## Trabalhando coluna de idade

# %%
db["IDADE"].isnull().value_counts()
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %%
db[db["IDADE"].isnull()]["FAIXA IDADE"].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %%
media_17_21 = db[db["FAIXA IDADE"]=="17-21"]["IDADE"].mean()

# %%
db.loc[(db["FAIXA IDADE"]=="17-21") & (db["IDADE"].isnull()), "IDADE"] = media_17_21

# %%
db[db["IDADE"].isnull()]["FAIXA IDADE"].value_counts()
# Out:
# FAIXA IDADE
# 55+    68
# Name: count, dtype: int64

# %%
db[db["FAIXA IDADE"]=="55+"]["IDADE"]
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %%
db[db["FAIXA IDADE"]=="55+"]["NIVEL"]
# Out:
# 9        Pleno
# 66      Júnior
# 96       Pleno
# 121      Pleno
# 156     Júnior
#          ...
# 4001       NaN
# 4043       NaN
# 4048       NaN
# 4061       NaN
# 4215    Sênior
# Name: NIVEL, Length: 68, dtype: object

# %%
media_geral = db["IDADE"].mean()
media_geral
# Out:
# np.float64(31.153517220250375)

# %%
db.loc[(db["FAIXA IDADE"]=="55+") & (db["IDADE"].isnull()), "IDADE"] = media_geral

# %%
db[db["IDADE"].isnull()]["FAIXA IDADE"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ### Tratando coluna salário

# %%
db[db["SALARIO"].isnull()]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 12            12  zwr9hqcpg513kaopenzwr9hibaqmldto   31.0       30-34
# 28            28  ztgepgj82o9oix0nztgepq2trcay6gpv   24.0       22-24
# 34            34  zsa9i6njd3e594mw0tvlk4zsa9iw86i9   24.0       22-24
# 39            39  zr4b2vm7dapp3linwqwn7zr4b2vmagqx   32.0       30-34
# 63            63  zm7o5yquakof0j6zm7vh3o0letznhdvh   26.0       25-29
# ...          ...                               ...    ...         ...
# 4242        4242  09oxwp6lsdwhw09ox1uobuxa8cq2pzma   26.0       25-29
# 4252        4252  064pe9b1htw7mflhif064pe95dotv6yf   39.0       35-39
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 12    Masculino         Branca  Não
# 28     Feminino          Parda  Não
# ...

# %%
db[db["SALARIO"].isnull()]["FAIXA SALARIAL"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
mediana_salario = db["SALARIO"].median()

# %%
db.loc[db["SALARIO"].isnull(), "SALARIO"] = mediana_salario

# %%
db[db["SALARIO"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, IDADE, FAIXA IDADE, GENERO, COR/RACA/ETNIA, PCD, EXPERIENCIA_PROFISSIONAL_PREJUDICADA, ASPECTOS_PREJUDICADOS, VIVE_NO_BRASIL, ESTADO ONDE MORA, UF ONDE MORA, REGIAO ONDE MORA, MUDOU DE ESTADO?, REGIAO DE ORIGEM, NIVEL DE ENSINO, ÁREA DE FORMAÇÃO, QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?, SETOR, NUMERO DE FUNCIONARIOS, GESTOR?, CARGO COMO GESTOR, CARGO ATUAL, NIVEL, FAIXA SALARIAL, QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?, QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?, SALARIO]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# # Valores discrepantes (outliers)

# %%
lista_idades = [26,30,32,22,26,35,400,20,43,31,23]

# %%
media = np.mean(lista_idades)
media
# Out:
# np.float64(62.54545454545455)

# %%
desvio = np.std(lista_idades)
desvio
# Out:
# np.float64(106.89532997398872)

# %%
media + 3*desvio
# Out:
# np.float64(383.2314444674207)

# %%
media - 3*desvio
# Out:
# np.float64(-258.1405353765116)

# %%
plt.boxplot(lista_idades)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1246ccb90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1246cd190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12408ddc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1246cd7c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1246cdaf0>],
#  'means': []}

# %%
plt.boxplot(db["SALARIO"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1246a41d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1246a4800>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1246bbf50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1246a4dd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1246a5070>],
#  'means': []}

# %%
Q1 = db["SALARIO"].quantile(0.25)
Q1
# Out:
# np.float64(4751.5)

# %%
Q3 = db["SALARIO"].quantile(0.75)
Q3
# Out:
# np.float64(11794.5)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(7043.0)

# %%
lim_superior = Q3 + (1.5*IQR)
lim_superior
# Out:
# np.float64(22359.0)

# %%
lim_inferior = Q1 - (1.5*IQR)
lim_inferior
# Out:
# np.float64(-5813.0)

# %%
db["FAIXA SALARIAL"].value_counts()
# Out:
# FAIXA SALARIAL
# de R$ 8.001/mês a R$ 12.000/mês     752
# de R$ 4.001/mês a R$ 6.000/mês      584
# de R$ 6.001/mês a R$ 8.000/mês      527
# de R$ 12.001/mês a R$ 16.000/mês    437
# de R$ 3.001/mês a R$ 4.000/mês      303
# de R$ 2.001/mês a R$ 3.000/mês      285
# de R$ 16.001/mês a R$ 20.000/mês    229
# de R$ 1.001/mês a R$ 2.000/mês      216
# de R$ 20.001/mês a R$ 25.000/mês    134
# de R$ 25.001/mês a R$ 30.000/mês     77
# de R$ 30.001/mês a R$ 40.000/mês     70
# Acima de R$ 40.001/mês               45
# Menos de R$ 1.000/mês                35
# Name: count, dtype: int64

# %%
media_salario = db["SALARIO"].mean()
media_salario
# Out:
# np.float64(10517.53348162023)

# %%
desvio_salario = db["SALARIO"].std()
desvio_salario
# Out:
# np.float64(18096.21098911858)

# %%
limite_superior = media_salario + (3*desvio_salario)
limite_superior
# Out:
# np.float64(64806.166448975964)

# %%
db[db["SALARIO"]>limite_superior]["FAIXA SALARIAL"].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês              19
# de R$ 30.001/mês a R$ 40.000/mês     3
# Name: count, dtype: int64

# %%
media_30_40 = db[(db["FAIXA SALARIAL"]=="de R$ 30.001/mês a R$ 40.000/mês") & (db["SALARIO"]<limite_superior)]["SALARIO"].mean()

# %%
db.loc[(db["FAIXA SALARIAL"]=="de R$ 30.001/mês a R$ 40.000/mês") & (db["SALARIO"]>limite_superior), "SALARIO"] = media_30_40

# %%
db[db["SALARIO"]>limite_superior]["FAIXA SALARIAL"].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês    19
# Name: count, dtype: int64

# %%
acima_40 = db[(db["FAIXA SALARIAL"]=="Acima de R$ 40.001/mês") & (db["SALARIO"]<limite_superior)]["SALARIO"].mean()

# %%
db.loc[(db["FAIXA SALARIAL"]=="Acima de R$ 40.001/mês") & (db["SALARIO"]>limite_superior), "SALARIO"] = acima_40

# %%
db[db["SALARIO"]>limite_superior]["FAIXA SALARIAL"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
plt.boxplot(db["SALARIO"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1248c47a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1248c4cb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1246579e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1248c5220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1248c5460>],
#  'means': []}

# %% [markdown]
# # Distribuição Amostral e Intervalo de Confiança

# %%
salarios = db["SALARIO"]
salarios
# Out:
# 0       11194.0
# 1        4695.0
# 2       14202.0
# 3       15463.0
# 4        7733.0
#          ...
# 4266     4329.0
# 4267     3758.0
# 4268    19607.0
# 4269      989.0
# 4270     3079.0
# Name: SALARIO, Length: 4271, dtype: float64

# %%
media_amostral = np.mean(salarios)
media_amostral
# Out:
# np.float64(9904.390109813306)

# %%
desvio_amostral = np.std(salarios)
desvio_amostral
# Out:
# np.float64(8306.104872579352)

# %%
nivel_confianca = 0.95

# %%
tamanho_amostra = len(salarios)
tamanho_amostra
# Out:
# 4271

# %%
erro_padrao = stats.sem(salarios)
erro_padrao
# Out:
# np.float64(127.11109872023638)

# %%
intervalo_confianca = stats.t.interval(nivel_confianca,tamanho_amostra-1,loc=media_amostral,scale=erro_padrao)
intervalo_confianca
# Out:
# (np.float64(9655.186295869078), np.float64(10153.593923757535))

# %% [markdown]
# ## 90% de confiança, média salarial por cargo e por gênero

# %%
generos = db.groupby("GENERO")

# %%
media = generos["SALARIO"].mean()

# %%
desvio = generos["SALARIO"].std()

# %%
tamanho = generos["SALARIO"].count()

# %%
nivel_confianca = 0.90

# %%
erro_padrao = desvio_amostral / np.sqrt(tamanho)
erro_padrao = stats.sem(salarios)

# %%
intervalo_confianca = stats.t.interval(nivel_confianca,tamanho-1,loc=media,scale=erro_padrao)
intervalo_confianca
# Out:
# (array([ 8272.99357855, 10184.41615434,  6798.36440725]),
#  array([ 8691.51938765, 10602.69581364,  7236.82606894]))

# %%
cargos = db.groupby("GESTOR?")

# %% [markdown]
# # Featuring Engineering

# %%
def preencher_nivel(gestor,nivel):
    if gestor == 1:
        return "Pessoa Gestora"
    else:
        return nivel

# %%
db["NOVO NIVEL"] = db.apply(lambda x: preencher_nivel(x["GESTOR?"],x["NIVEL"]), axis=1)

# %%
db["NOVO NIVEL"].value_counts()
# Out:
# NOVO NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa Gestora     713
# Name: count, dtype: int64

# %%
db["NIVEL"]
# Out:
# 0       Júnior
# 1          NaN
# 2        Pleno
# 3       Sênior
# 4        Pleno
#          ...
# 4266     Pleno
# 4267     Pleno
# 4268       NaN
# 4269    Júnior
# 4270    Júnior
# Name: NIVEL, Length: 4271, dtype: object

# %%
db = pd.get_dummies(db,columns=["NIVEL"])

# %%
db.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior'],
#       dtype='object')

# %%
def determinar_geracao(idade):
    if 39<idade<=58:
        return "Geração X"
    elif 29<idade<=39:
        return "Millenial"
    elif 13<idade<=29:
        return "Geração Z"
    else:
        return "Outra geração"

# %%
db["GERAÇÃO"] = db["IDADE"].apply(determinar_geracao)

# %%
db["GERAÇÃO"].value_counts()
# Out:
# GERAÇÃO
# Geração Z    1999
# Millenial    1761
# Geração X     511
# Name: count, dtype: int64

# %%
db2 = pd.read_excel("/Users/anacariane/Desktop/programaria/Planilha_Aula_parte2.xlsx")

# %%
db2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
# ...

# %%
db = db.merge(db2, on="ID", how="left")

# %%
db.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERAÇÃO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
db["Você pretende mudar de emprego nos próximos 6 meses?"].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
db["EM BUSCA"] = db["Você pretende mudar de emprego nos próximos 6 meses?"].str.contains("em busca", case=False)

# %%
db["EM BUSCA"].value_counts()
# Out:
# EM BUSCA
# False    2332
# True     1364
# Name: count, dtype: int64

# %%
db["ABERTO OPORTUNIDADES"] = db["Você pretende mudar de emprego nos próximos 6 meses?"].str.contains("aberto", case=False)

# %%
db["ABERTO OPORTUNIDADES"].value_counts()
# Out:
# ABERTO OPORTUNIDADES
# False    2342
# True     1354
# Name: count, dtype: int64

# %% [markdown]
# # Correlação

# %%
correlacao_continua = db["IDADE"].corr(db["SALARIO"])
correlacao_continua
# Out:
# np.float64(0.2902441968622097)

# %%
from scipy.stats import chi2_contingency

# %%
def cramer_coeficiente(coluna1, coluna2):
    tabela_cruzada = np.array(pd.crosstab(coluna1,coluna2))
    chi2 = chi2_contingency(tabela_cruzada)[0]
    soma = np.sum(tabela_cruzada)
    mini = min(tabela_cruzada.shape)-1
    cramer = np.sqrt(chi2/(soma*mini))
    return cramer

# %%
cramer_coeficiente(db["COR/RACA/ETNIA"], db["NIVEL DE ENSINO"])
# Out:
# np.float64(0.04499106580480143)

# %%
tabela_cruzada = pd.crosstab(db["COR/RACA/ETNIA"], db["NIVEL DE ENSINO"])
tabela_cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# COR/RACA/ETNIA
# Amarela                              7                      15
# Branca                             127                     365
# Indígena                             0                       2
# Outra                                0                       0
# Parda                               50                     178
# Prefiro não informar                 1                       2
# Preta                                6                      51
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# COR/RACA/ETNIA
# Amarela                                  50        14
# Branca                                  999       355
# Indígena                                  4         2
# Outra                                     6         3
# Parda                                   333       113
# Prefiro não informar                     14         1
# ...

# %% [markdown]
# ## Nova coluna de etnia: branca, não branca e outros

# %%
db["COR/RACA/ETNIA"].value_counts()
# Out:
# COR/RACA/ETNIA
# Branca                  2746
# Parda                   1054
# Preta                    291
# Amarela                  128
# Prefiro não informar      26
# Outra                     17
# Indígena                  11
# Name: count, dtype: int64

# %%
db["BRANCA_COR/RACA/ETNIA"] = db["COR/RACA/ETNIA"].str.contains("Branca", case=False)

# %%
db["BRANCA_COR/RACA/ETNIA"].value_counts()
# Out:
# BRANCA_COR/RACA/ETNIA
# True     2746
# False    1527
# Name: count, dtype: int64

# %%
db["OUTRAS_COR/RAÇA/ETNIA"] = db["COR/RACA/ETNIA"].str.contains("Outra", case=False)

# %%
db["OUTRAS_COR/RAÇA/ETNIA"].value_counts()
# Out:
# OUTRAS_COR/RAÇA/ETNIA
# False    4256
# True       17
# Name: count, dtype: int64

# %%
db["NÃO BRANCA_COR/RAÇA/ETNIA"] = db["COR/RACA/ETNIA"].str.contains("Branca", "Outra", case=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 db["NÃO BRANCA_COR/RAÇA/ETNIA"] = db["COR/RACA/ETNIA"].str.contains("Branca", "Outra", case=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/strings/accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.contains() got multiple values for argument 'case'

# %% [markdown]
# # Salvando a análise de dados

# %%
db.to_csv("/Users/anacariane/Desktop/programaria/analisedados.csv", index=False)

# %% [markdown]
# # Conectando SQL com Pandas

# %%
import sqlite3

# %%
conexao = sqlite3.connect("/Users/anacariane/Desktop/programaria/status_brasil")
conexao

# %%
query = "SELECT * FROM Municipios_Brasileiros WHERE cidade = 'Itaquaquecetuba';"
query
# Out:
# "SELECT * FROM Municipios_Brasileiros WHERE cidade = 'Itaquaquecetuba';"

# %%
a = "batata"

# %%
print("eu gosto de {}".format(a))
# Out:
# eu gosto de batata

# %%
a = ["batata", "tomate", "alface"]

# %%
print("Eu gosto de {}, {}, {}".format(a[0], a[1], a[2]))
# Out:
# Eu gosto de batata, tomate, alface

# %%
print("Eu gosto de {}".format(",".join(a)))
# Out:
# Eu gosto de batata,tomate,alface

# %%
db.rename(columns={"UF ONDE MORA": "estado"}, inplace=True)

# %%
db.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'estado', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO',
#        'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERAÇÃO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
# ...

# %%
lista_estados = list (db["estado"].unique())
lista_estados
# Out:
# ['DF',
#  'PA',
#  'MG',
#  'CE',
#  'SP',
#  'RS',
#  'BA',
#  'RJ',
#  'MS',
#  'PB',
#  'MT',
#  'PR',
#  'ES',
#  nan,
#  'SC',
#  'PE',
#  'RN',
#  'SE',
#  'AL',
#  'GO',
#  'MA',
#  'AM',
#  'PI']

# %%
#db.to_csv("/Users/anacariane/Desktop/programaria/analisedados.csv", index=False)

# %%
#db = pd.read_csv("/Users/anacariane/Desktop/programaria/analisedados.csv")

# %%
query = '''SELECT Municipios_Brasileiros.estado, AVG(Municipios_Status.renda) FROM Municipios_Brasileiros
        INNER JOIN Municipios_Status ON Municipios_Brasileiros.municipio_ID  = Municipios_Status.municipio_ID
        WHERE Municipios_Brasileiros.estado IN ({}) 
        GROUP BY Municipios_Brasileiros.estado;''' .format(",".join(["?" for _ in lista_estados]))

# %%
print(query)
# Out:
# SELECT Municipios_Brasileiros.estado, AVG(Municipios_Status.renda) FROM Municipios_Brasileiros
#         INNER JOIN Municipios_Status ON Municipios_Brasileiros.municipio_ID  = Municipios_Status.municipio_ID
#         WHERE Municipios_Brasileiros.estado IN (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
#         GROUP BY Municipios_Brasileiros.estado;

# %%
estados_renda = pd.read_sql(query, con=conexao, params=lista_estados)

# %%
db = db.merge(estados_renda, on="estado", how="left")

# %%
correlacao_renda_salario = db["SALARIO"].corr(db["AVG(Municipios_Status.renda)"])
correlacao_renda_salario
# Out:
# np.float64(0.12083384881429411)

# %%
#cheia 📌Faça a mesma análise utilizando o índice de educação. Existe alguma correlação com salário?🤔
query2 = '''SELECT Municipios_Brasileiros.estado, AVG(Municipios_Status.educacao) FROM Municipios_Brasileiros
        INNER JOIN Municipios_Status ON Municipios_Brasileiros.municipio_ID  = Municipios_Status.municipio_ID
        WHERE Municipios_Brasileiros.estado IN ({}) 
        GROUP BY Municipios_Brasileiros.estado;''' .format(",".join(["?" for _ in lista_estados]))

# %%
print(query2)
# Out:
# SELECT Municipios_Brasileiros.estado, AVG(Municipios_Status.educacao) FROM Municipios_Brasileiros
#         INNER JOIN Municipios_Status ON Municipios_Brasileiros.municipio_ID  = Municipios_Status.municipio_ID
#         WHERE Municipios_Brasileiros.estado IN (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
#         GROUP BY Municipios_Brasileiros.estado;

# %%
educacao_renda2 = pd.read_sql(query2, con=conexao, params=lista_estados)

# %%
db = db.merge(educacao_renda2, on="estado", how="left")

# %%
correlacao_renda_educacao = db["SALARIO"].corr(db["AVG(Municipios_Status.educacao)"])
correlacao_renda_educacao
# Out:
# np.float64(0.15558020288268745)

# %% [markdown]
# # Visualização de Dados

# %%
import pandas as pd

# %%
db = pd.read_csv('/Users/anacariane/Desktop/programaria/analisedados.csv')

# %%
db.head()
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
# ...

# %%
genero_counts = db["GENERO"].value_counts()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.bar(height = genero_counts.values, x = genero_counts.index)
plt.title("Quantidade de pessoas por Gênero na área de Dados")
plt.xlabel("Gênero")
plt.ylabel("Contagem")
plt.show()

# %%
import seaborn as sns

# %%
plt.figure()
sns.countplot(data = db, x = "GENERO", palette = "pastel")
plt.title("Quantidade de pessoas por Gênero na área de Dados")
plt.xlabel("Gênero")
plt.ylabel("Contagem")
plt.grid(True)
plt.show()
# Out:
# /var/folders/5_/6j8429dj47z_h611_0h64fc00000gn/T/ipykernel_60099/4198010655.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
salario_por_idade = db.groupby("IDADE")["SALARIO"].mean()

# %%
salario_por_idade
# Out:
# IDADE
# 18.000000     4230.307692
# 19.000000     4519.590909
# 20.000000     5004.272727
# 20.205479     3536.000000
# 21.000000     4578.737179
# 22.000000     4394.689815
# 23.000000     5602.406897
# 24.000000     6151.622449
# 25.000000     7616.392336
# 26.000000     7700.071174
# 27.000000     8237.429766
# 28.000000     9737.938144
# 29.000000     9554.853147
# 30.000000    10316.412686
# 31.000000    10021.462609
# 31.153517     9646.330882
# 32.000000    10843.197778
# 33.000000    11592.718590
# 34.000000    12294.640212
# 35.000000    12435.845105
# 36.000000    12267.966533
# 37.000000    12613.528357
# 38.000000    13802.724874
# 39.000000    13309.082898
# 40.000000    15028.032721
# 41.000000    13578.880952
# 42.000000    11801.037037
# 43.000000    14349.732278
# 44.000000    14665.770147
# 45.000000    16103.431520
# 46.000000    11913.709677
# 47.000000    11156.031250
# 48.000000    12249.714286
# 49.000000    14556.000000
# 50.000000    15740.010181
# ...

# %%
plt.figure()
plt.plot(salario_por_idade.index, salario_por_idade.values, marker="o", linestyle="--")
plt.xlabel("Idade")
plt.ylabel("Média de Salário")
plt.title("Média de Salário por Idade")
plt.grid(True)
plt.show()

# %%
import plotly.express as px

# %%
fig = px.line(salario_por_idade.reset_index(), x="IDADE", y="SALARIO", title="Média de Salário por Idade", markers=True)
fig.show()

# %%
plt.figure(figsize=(20,5))
plt.scatter(db["IDADE"], db["SALARIO"], alpha=0.5)
plt.xlabel("Idade")
plt.ylabel("Média de Salário")
plt.title("Dispersão de Salário por Idade")
plt.grid(True)
plt.show()

# %%
fig = px.scatter(db, x="IDADE", y="SALARIO", title="Dispersão de Salário por Idade")
fig.show()

# %% [markdown]
# ## 6.3 Faça você mesme

# %%
db_nova = pd.read_csv('/Users/anacariane/Desktop/programaria/municipios_brasileiros.csv')

# %%
db_nova.head()
# Out:
#    codigo_ibge       nome_municipio  codigo_uf  uf        estado  capital  \
# 0      5200050      Abadia de Goiás         52  GO         Goiás        0
# 1      3100104  Abadia dos Dourados         31  MG  Minas Gerais        0
# 2      5200100            Abadiânia         52  GO         Goiás        0
# 3      3100203               Abaeté         31  MG  Minas Gerais        0
# 4      1500107           Abaetetuba         15  PA          Pará        0
#
#    latitude  longitude
# 0 -16.75730   -49.4412
# 1 -18.48310   -47.3916
# 2 -16.19700   -48.7057
# 3 -19.15510   -45.4444
# 4  -1.72183   -48.8788

# %%
db_nova.columns
# Out:
# Index(['codigo_ibge', 'nome_municipio', 'codigo_uf', 'uf', 'estado', 'capital',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
fig = px.scatter(db_nova, x="latitude", y="longitude", title="...")
fig.show()

# %%
lat_lon = db_nova.groupby("latitude")["longitude"].mean()

# %%
fig = px.line(lat_lon.reset_index(), x="latitude", y="longitude", title="...", markers=True)
fig.show()

# %%
db.to_csv("/Users/anacariane/Desktop/programaria/analise_dados.csv", index=False)
